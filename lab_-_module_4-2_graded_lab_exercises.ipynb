# %%
# Instructions:
# Create functions that will take two arguments:

# function name: myAddfunc
# task: to perform math addition operation and return the value

# function name: mySubfunc
# task: to perform math subraction operation and return the value

# function name: myMulfunc
# task: to perform math mutiplication operation and return the value

# function name: myDivfunc
# task: to perform math division operation and return the value

# Create a main menu to display the following:

# Press 1: Do Mathetical function
# Press 2: Get the IP address
# Press 3: Exit

# If Option 1 on the main menu is selected the following Sub-menus must be displayed for 
# the following mathematical operation to be selected, use the functions you created previously 
# to calculate the selected mathematical operations for two numbers entered by the user through an input() function.         

# Press 1: Additions.
# Press 2: Subtractions. 
# Press 3: Multiplications.
# Press 4: Divisions.
# Press 5: Exit Operation.

# Note: If option 5 is selected or any other options not specified within the Sub-menu, ti should go back to the main menu.

# If Option 2 on the main menu is selected, a user prompt to enter the hostname; 
# check if the hostname is in dict and display its IP address, 
# if not in dict prompt the user the hostname is not in the record. 
# Keep on asking to enter a hostname until it wants to exit and must go back to the main menu.

# If Option 3 on the main menu is selected, terminate the program.

dict = {"R1":"172.16.16.100","R2":"192.168.1.10","R3":"192.168.1.11","S1":"192.168.88.1","S2":"192.168.88.2"}

# Provide your code below:

def myAddfunc(a,b):
    c = a+b
    return c

def mySubfunc(a,b):
    c = a-b
    return c

def myMulfunc(a,b):
    c = a*b
    return c

def myDivfunc(a,b):
    c = round(a/b,2)
    return c


while True:
    
    mainmenu = input("Main Menu is:\n Press 1: Do Mathetical function\n Press 2: Get the IP address\n Press 3: Exit\n")
    
    if mainmenu == "1":
        while True:
            mathop = input("Math Menu is: \n Press 1: Additions\n Press 2: Subtractions\n Press 3: Multiplications\n Press 4: Divisions\n Press 5: Exit Operation.")
            if mathop == "1":
                n1 = float(input("\tEnter first number: "))
                n2 = float(input("\tEnter second number: "))
                print(f"\tAddition of {n1} and {n2} is: {myAddfunc(n1,n2)}.")
                continue
            elif mathop == "2":
                n1 = float(input("\tEnter first number: "))
                n2 = float(input("\tEnter second number: "))
                print(f"\tSubtraction of {n1} and {n2} is: {mySubfunc(n1,n2)}.")
                continue
            elif mathop == "3":
                n1 = float(input("\tEnter first number: "))
                n2 = float(input("\tEnter second number: "))
                print(f"\tMultiplication of {n1} and {n2} is: {myMulfunc(n1,n2)}.")
                continue
            elif mathop == "4":
                n1 = float(input("\tEnter first number: "))
                n2 = float(input("\tEnter second number: "))
                print(f"\tDivision of {n1} and {n2} is: {myDivfunc(n1,n2)}.")
                continue
            elif mathop == "5":
                print("\tExited!")
                break
            else:
                print(f"\tNot a correct mathop {mathop}.")
                break

    elif mainmenu == "2":
        while True: 
            hostname = input("\tEnter the hostname. ")
            if hostname.lower() == "exit":
                break
            elif hostname in dict:
                print("\t",dict[hostname])
                continue
            else:
                print("\tNot a valid hostname.\n")
                continue
                
    elif mainmenu == "3":
        print("\tTerminated the program.\n")
        break
    
    else:
        continue
# Out:
# Main Menu is:
#  Press 1: Do Mathetical function
#  Press 2: Get the IP address
#  Press 3: Exit
# 1
# Math Menu is:
#  Press 1: Additions
#  Press 2: Subtractions
#  Press 3: Multiplications
#  Press 4: Divisions
#  Press 5: Exit Operation.1
# 	Enter first number: 4.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 70
#      68 mathop = input("Math Menu is: \n Press 1: Additions\n Press 2: Subtractions\n Press 3: Multiplications\n Press 4: Divisions\n Press 5: Exit Operation.")
#      69 if mathop == "1":
# ---> 70     n1 = int(input("\tEnter first number: "))
#      71     n2 = int(input("\tEnter second number: "))
#      72     print(f"\tAddition of {n1} and {n2} is: {myAddfunc(n1,n2)}.")
#
# ValueError: invalid literal for int() with base 10: '4.5'
